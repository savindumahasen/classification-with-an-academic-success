# %% [markdown]
# # Classification with an academic success

# %%
## import the training and test dataset

# %%
import pandas as pd

training_set=pd.read_csv("train.csv")
testing_set=pd.read_csv("test.csv")

# %%
training_set.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# 2                           137.0            1                       3  ...
# 3                           131.0            1                      19  ...
# 4                           132.0            1                      19  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    6
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    8
# 4                                    0                                    7
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       7
# 1                                       9
# 2                                       0
# 3                                      11
# 4                                      12
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    6                         12.428571
# 1                                    0                          0.000000
# 2                                    0                          0.000000
# 3                                    7                         12.820000
# 4                                    6                         12.933333
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               11.1
# 1                                               0               11.1
# 2                                               0               16.2
# 3                                               0               11.1
# 4                                               0                7.6
#
#    Inflation rate   GDP    Target
# 0             0.6  2.02  Graduate
# 1             0.6  2.02   Dropout
# 2             0.3 -0.92   Dropout
# 3             0.6  2.02  Enrolled
# 4             2.6  0.32  Graduate
#
# [5 rows x 38 columns]

# %%
## getting the information about the training dataset

# %%
training_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
#  9   Mother's qualification                          76518 non-null  int64
#  10  Father's qualification                          76518 non-null  int64
#  11  Mother's occupation                             76518 non-null  int64
#  12  Father's occupation                             76518 non-null  int64
#  13  Admission grade                                 76518 non-null  float64
#  14  Displaced                                       76518 non-null  int64
#  15  Educational special needs                       76518 non-null  int64
#  16  Debtor                                          76518 non-null  int64
#  17  Tuition fees up to date                         76518 non-null  int64
#  18  Gender                                          76518 non-null  int64
#  19  Scholarship holder                              76518 non-null  int64
#  20  Age at enrollment                               76518 non-null  int64
#  21  International                                   76518 non-null  int64
#  22  Curricular units 1st sem (credited)             76518 non-null  int64
#  23  Curricular units 1st sem (enrolled)             76518 non-null  int64
#  24  Curricular units 1st sem (evaluations)          76518 non-null  int64
#  25  Curricular units 1st sem (approved)             76518 non-null  int64
#  26  Curricular units 1st sem (grade)                76518 non-null  float64
#  27  Curricular units 1st sem (without evaluations)  76518 non-null  int64
#  28  Curricular units 2nd sem (credited)             76518 non-null  int64
#  29  Curricular units 2nd sem (enrolled)             76518 non-null  int64
#  30  Curricular units 2nd sem (evaluations)          76518 non-null  int64
#  31  Curricular units 2nd sem (approved)             76518 non-null  int64
#  32  Curricular units 2nd sem (grade)                76518 non-null  float64
#  33  Curricular units 2nd sem (without evaluations)  76518 non-null  int64
#  34  Unemployment rate                               76518 non-null  float64
#  35  Inflation rate                                  76518 non-null  float64
#  36  GDP                                             76518 non-null  float64
#  37  Target                                          76518 non-null  object
# dtypes: float64(7), int64(30), object(1)
# memory usage: 22.2+ MB

# %%
## seperate the target variable from the training dataset

# %%
training_set_label = training_set.Target.copy

# %%
training_set_label
# Out:
# <bound method NDFrame.copy of 0        Graduate
# 1         Dropout
# 2         Dropout
# 3        Enrolled
# 4        Graduate
#            ...
# 76513    Graduate
# 76514    Graduate
# 76515    Enrolled
# 76516     Dropout
# 76517    Graduate
# Name: Target, Length: 76518, dtype: object>

# %% [markdown]
# ## Explotary Data Analysis (EDA)

# %%
## print the first five records

# %%
 training_set.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# 2                           137.0            1                       3  ...
# 3                           131.0            1                      19  ...
# 4                           132.0            1                      19  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    6
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    8
# 4                                    0                                    7
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       7
# 1                                       9
# 2                                       0
# 3                                      11
# 4                                      12
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    6                         12.428571
# 1                                    0                          0.000000
# 2                                    0                          0.000000
# 3                                    7                         12.820000
# 4                                    6                         12.933333
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               11.1
# 1                                               0               11.1
# 2                                               0               16.2
# 3                                               0               11.1
# 4                                               0                7.6
#
#    Inflation rate   GDP    Target
# 0             0.6  2.02  Graduate
# 1             0.6  2.02   Dropout
# 2             0.3 -0.92   Dropout
# 3             0.6  2.02  Enrolled
# 4             2.6  0.32  Graduate
#
# [5 rows x 38 columns]

# %%
## correlational analysis

# %%
## categorize the target variable

# %%
training_set["Target"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 76518 entries, 0 to 76517
# Series name: Target
# Non-Null Count  Dtype
# --------------  -----
# 76518 non-null  object
# dtypes: object(1)
# memory usage: 597.9+ KB

# %%
training_set.replace({'Target':{'Graduate':0,'Dropout':1,'Enrolled':2}}, inplace=True)

# %%
training_set.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# 2                           137.0            1                       3  ...
# 3                           131.0            1                      19  ...
# 4                           132.0            1                      19  ...
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    6
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    8
# 4                                    0                                    7
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       7
# 1                                       9
# 2                                       0
# 3                                      11
# 4                                      12
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    6                         12.428571
# 1                                    0                          0.000000
# 2                                    0                          0.000000
# 3                                    7                         12.820000
# 4                                    6                         12.933333
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               11.1
# 1                                               0               11.1
# 2                                               0               16.2
# 3                                               0               11.1
# 4                                               0                7.6
#
#    Inflation rate   GDP  Target
# 0             0.6  2.02       0
# 1             0.6  2.02       1
# 2             0.3 -0.92       1
# 3             0.6  2.02       2
# 4             2.6  0.32       0
#
# [5 rows x 38 columns]

# %%
training_set_pd_corr=training_set.corr()

# %%
pd.set_option('display.max_rows', None)
training_set_pd_corr.head()
# Out:
#                          id  Marital status  Application mode  \
# id                 1.000000        0.009796         -0.003956
# Marital status     0.009796        1.000000          0.307324
# Application mode  -0.003956        0.307324          1.000000
# Application order -0.007129       -0.113951         -0.238497
# Course             0.002111        0.023141          0.040452
#
#                    Application order    Course  Daytime/evening attendance  \
# id                         -0.007129  0.002111                    0.002192
# Marital status             -0.113951  0.023141                   -0.323587
# Application mode           -0.238497  0.040452                   -0.354834
# Application order           1.000000  0.054168                    0.147153
# Course                      0.054168  1.000000                   -0.041557
#
#                    Previous qualification  Previous qualification (grade)  \
# id                              -0.005403                       -0.003635
# Marital status                   0.084064                       -0.037717
# Application mode                 0.451252                       -0.060636
# Application order               -0.155281                       -0.013956
# Course                          -0.011349                       -0.069488
#
#                    Nacionality  Mother's qualification  \
# id                    0.002437                0.001159
# Marital status        0.004660                0.198373
# Application mode      0.005937                0.163590
# Application order    -0.016601               -0.062138
# Course               -0.018786                0.018063
#
#                    Father's qualification  Mother's occupation  \
# id                              -0.003199             0.007027
# Marital status                   0.144820             0.069695
# Application mode                 0.102086             0.063062
# Application order               -0.046074            -0.037192
# Course                           0.022939             0.015827
#
#                    Father's occupation  Admission grade  Displaced  \
# id                            0.007252        -0.002445   0.005972
# Marital status                0.054671        -0.037388  -0.216122
# Application mode              0.045628        -0.071243  -0.323343
# Application order            -0.029156        -0.035714   0.347966
# Course                        0.015646        -0.089969  -0.070575
#
#                    Educational special needs    Debtor  \
# id                                 -0.002527 -0.005147
# Marital status                     -0.011644  0.049145
# Application mode                   -0.012460  0.153215
# Application order                   0.006566 -0.059187
# Course                             -0.014631 -0.020765
#
#                    Tuition fees up to date    Gender  Scholarship holder  \
# id                                0.002250 -0.004084           -0.003048
# Marital status                   -0.110193  0.031700           -0.075632
# Application mode                 -0.216764  0.240312           -0.209330
# Application order                 0.064854 -0.122433            0.092768
# Course                            0.016522 -0.106512            0.041961
#
#                    Age at enrollment  International  \
# id                         -0.000624      -0.000089
# Marital status              0.552404      -0.004286
# Application mode            0.593664       0.005971
# Application order          -0.240258      -0.016731
# Course                      0.023751      -0.015163
#
#                    Curricular units 1st sem (credited)  \
# id                                           -0.009064
# Marital status                                0.039838
# Application mode                              0.174309
# Application order                            -0.073493
# Course                                       -0.067790
#
#                    Curricular units 1st sem (enrolled)  \
# id                                           -0.005707
# Marital status                                0.007968
# Application mode                              0.045741
# Application order                             0.109712
# Course                                        0.576324
#
#                    Curricular units 1st sem (evaluations)  \
# id                                              -0.004012
# Marital status                                   0.008848
# Application mode                                 0.101746
# Application order                               -0.029603
# Course                                           0.327168
#
#                    Curricular units 1st sem (approved)  \
# id                                           -0.002580
# Marital status                               -0.107198
# Application mode                             -0.246015
# Application order                             0.143060
# Course                                        0.259981
#
#                    Curricular units 1st sem (grade)  \
# id                                        -0.000801
# Marital status                            -0.104684
# Application mode                          -0.248152
# Application order                          0.097291
# Course                                     0.344706
#
#                    Curricular units 1st sem (without evaluations)  \
# id                                                       0.003339
# Marital status                                           0.023511
# Application mode                                         0.033103
# Application order                                       -0.018316
# Course                                                   0.012660
#
#                    Curricular units 2nd sem (credited)  \
# id                                           -0.007880
# Marital status                                0.037268
# Application mode                              0.159977
# Application order                            -0.066853
# Course                                       -0.066453
#
#                    Curricular units 2nd sem (enrolled)  \
# id                                           -0.001978
# Marital status                               -0.005177
# Application mode                              0.013383
# Application order                             0.150224
# Course                                        0.613658
#
#                    Curricular units 2nd sem (evaluations)  \
# id                                              -0.004794
# Marital status                                  -0.021254
# Application mode                                 0.047992
# Application order                               -0.005080
# Course                                           0.328303
#
#                    Curricular units 2nd sem (approved)  \
# id                                           -0.001264
# Marital status                               -0.111369
# Application mode                             -0.274728
# Application order                             0.166433
# Course                                        0.249484
#
#                    Curricular units 2nd sem (grade)  \
# id                                         0.000206
# Marital status                            -0.111216
# Application mode                          -0.271664
# Application order                          0.106326
# Course                                     0.316896
#
#                    Curricular units 2nd sem (without evaluations)  \
# id                                                      -0.003217
# Marital status                                           0.025689
# Application mode                                         0.043298
# Application order                                       -0.019871
# Course                                                   0.018007
#
#                    Unemployment rate  Inflation rate       GDP    Target
# id                         -0.001539        0.000648  0.002916 -0.001746
# Marital status             -0.034481        0.019523 -0.046165  0.047468
# Application mode            0.098439        0.005130 -0.065964  0.178354
# Application order          -0.066022       -0.004206  0.031860 -0.113817
# Course                     -0.001982        0.007152  0.024719 -0.048335

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
training_set_pd_corr["Target"].sort_values(ascending=False)
# Out:
# Target                                            1.000000
# Gender                                            0.212961
# Application mode                                  0.178354
# Age at enrollment                                 0.131291
# Debtor                                            0.102055
# Curricular units 1st sem (evaluations)            0.095589
# Curricular units 2nd sem (evaluations)            0.084115
# Curricular units 2nd sem (without evaluations)    0.068818
# Previous qualification                            0.056724
# Curricular units 1st sem (without evaluations)    0.053365
# Marital status                                    0.047468
# Mother's occupation                               0.036347
# Father's occupation                               0.028271
# Mother's qualification                            0.020355
# Inflation rate                                    0.016117
# Nacionality                                       0.003061
# Educational special needs                         0.001606
# Father's qualification                            0.000066
# id                                               -0.001746
# International                                    -0.002008
# Curricular units 1st sem (credited)              -0.033397
# Curricular units 2nd sem (credited)              -0.036499
# Course                                           -0.048335
# Daytime/evening attendance                       -0.048478
# Unemployment rate                                -0.055411
# GDP                                              -0.066999
# Displaced                                        -0.084572
# Application order                                -0.113817
# Tuition fees up to date                          -0.137938
# Previous qualification (grade)                   -0.152562
# Admission grade                                  -0.153127
# Curricular units 1st sem (enrolled)              -0.188270
# Curricular units 2nd sem (enrolled)              -0.213194
# Curricular units 1st sem (grade)                 -0.272594
# Curricular units 2nd sem (grade)                 -0.291505
# Scholarship holder                               -0.327580
# Curricular units 1st sem (approved)              -0.406249
# Curricular units 2nd sem (approved)              -0.458061
# Name: Target, dtype: float64
