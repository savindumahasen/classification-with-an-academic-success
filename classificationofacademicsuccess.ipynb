# %% [markdown]
# # Classification with an academic success

# %%
## import the training and test dataset

# %%
import pandas as pd

training_set=pd.read_csv("train.csv")
testing_set=pd.read_csv("test.csv")

# %%
training_set.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# ...

# %%
## getting the information about the training dataset

# %%
training_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76518 entries, 0 to 76517
# Data columns (total 38 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id                                              76518 non-null  int64
#  1   Marital status                                  76518 non-null  int64
#  2   Application mode                                76518 non-null  int64
#  3   Application order                               76518 non-null  int64
#  4   Course                                          76518 non-null  int64
#  5   Daytime/evening attendance                      76518 non-null  int64
#  6   Previous qualification                          76518 non-null  int64
#  7   Previous qualification (grade)                  76518 non-null  float64
#  8   Nacionality                                     76518 non-null  int64
# ...

# %% [markdown]
# ## Explotary Data Analysis (EDA)

# %%
## print the first five records

# %%
 training_set.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# ...

# %%
## correlational analysis

# %%
## categorize the target variable

# %%
training_set["Target"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 76518 entries, 0 to 76517
# Series name: Target
# Non-Null Count  Dtype
# --------------  -----
# 76518 non-null  object
# dtypes: object(1)
# memory usage: 597.9+ KB

# %%
training_set.replace({'Target':{'Graduate':0,'Dropout':1,'Enrolled':2}}, inplace=True)

# %%
training_set.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  ...  \
# 0                           126.0            1                       1  ...
# 1                           125.0            1                      19  ...
# ...

# %%
training_set_pd_corr=training_set.corr()

# %%
pd.set_option('display.max_rows', None)
training_set_pd_corr.head()
# Out:
#                          id  Marital status  Application mode  \
# id                 1.000000        0.009796         -0.003956
# Marital status     0.009796        1.000000          0.307324
# Application mode  -0.003956        0.307324          1.000000
# Application order -0.007129       -0.113951         -0.238497
# Course             0.002111        0.023141          0.040452
#
#                    Application order    Course  Daytime/evening attendance  \
# id                         -0.007129  0.002111                    0.002192
# Marital status             -0.113951  0.023141                   -0.323587
# Application mode           -0.238497  0.040452                   -0.354834
# Application order           1.000000  0.054168                    0.147153
# Course                      0.054168  1.000000                   -0.041557
#
#                    Previous qualification  Previous qualification (grade)  \
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
training_set_pd_corr["Target"].sort_values(ascending=False)
# Out:
# Target                                            1.000000
# Gender                                            0.212961
# Application mode                                  0.178354
# Age at enrollment                                 0.131291
# Debtor                                            0.102055
# Curricular units 1st sem (evaluations)            0.095589
# Curricular units 2nd sem (evaluations)            0.084115
# Curricular units 2nd sem (without evaluations)    0.068818
# Previous qualification                            0.056724
# Curricular units 1st sem (without evaluations)    0.053365
# Marital status                                    0.047468
# Mother's occupation                               0.036347
# Father's occupation                               0.028271
# Mother's qualification                            0.020355
# Inflation rate                                    0.016117
# Nacionality                                       0.003061
# ...

# %%
from pandas.plotting import scatter_matrix

attribute= ["Target","Curricular units 1st sem (grade)","Curricular units 2nd sem (grade)",
 "Scholarship holder","Curricular units 1st sem (approved)","Curricular units 2nd sem (approved)"]

scatter_matrix(training_set[attribute], figsize=(30,32))
# Out:
# array([[<Axes: xlabel='Target', ylabel='Target'>,
#         <Axes: xlabel='Curricular units 1st sem (grade)', ylabel='Target'>,
#         <Axes: xlabel='Curricular units 2nd sem (grade)', ylabel='Target'>,
#         <Axes: xlabel='Scholarship holder', ylabel='Target'>,
#         <Axes: xlabel='Curricular units 1st sem (approved)', ylabel='Target'>,
#         <Axes: xlabel='Curricular units 2nd sem (approved)', ylabel='Target'>],
#        [<Axes: xlabel='Target', ylabel='Curricular units 1st sem (grade)'>,
#         <Axes: xlabel='Curricular units 1st sem (grade)', ylabel='Curricular units 1st sem (grade)'>,
#         <Axes: xlabel='Curricular units 2nd sem (grade)', ylabel='Curricular units 1st sem (grade)'>,
#         <Axes: xlabel='Scholarship holder', ylabel='Curricular units 1st sem (grade)'>,
#         <Axes: xlabel='Curricular units 1st sem (approved)', ylabel='Curricular units 1st sem (grade)'>,
# ...

# %%
## seperate the target variable from the training dataset

# %%
training_set_label = training_set['Target']

# %%
training_set_label.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    2
# 4    0
# Name: Target, dtype: int64

# %%
###   drop the target variable from  training dataset

# %%
training_set_pd = training_set.drop("Target", axis=1)

# %%
training_set_pd.head()
# Out:
#    id  Marital status  Application mode  Application order  Course  \
# 0   0               1                 1                  1    9238
# 1   1               1                17                  1    9238
# 2   2               1                17                  2    9254
# 3   3               1                 1                  3    9500
# 4   4               1                 1                  2    9500
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           126.0            1                       1
# 1                           125.0            1                      19
# ...

# %%
training_set_label
# Out:
# <bound method NDFrame.copy of 0        Graduate
# 1         Dropout
# 2         Dropout
# 3        Enrolled
# 4        Graduate
# 5         Dropout
# 6        Graduate
# 7        Graduate
# 8         Dropout
# 9        Graduate
# 10        Dropout
# 11        Dropout
# 12       Enrolled
# 13        Dropout
# 14        Dropout
# 15       Graduate
# 16        Dropout
# 17        Dropout
# 18       Graduate
# 19       Graduate
# 20        Dropout
# 21       Graduate
# 22       Graduate
# 23       Graduate
# 24       Graduate
# 25       Graduate
# 26       Graduate
# 27       Graduate
# 28        Dropout
# 29       Graduate
# 30       Enrolled
# 31       Enrolled
# 32       Graduate
# 33        Dropout
# 34       Graduate
# 35        Dropout
# 36        Dropout
# 37       Graduate
# 38       Enrolled
# 39        Dropout
# 40        Dropout
# 41        Dropout
# 42       Enrolled
# 43        Dropout
# 44       Graduate
# 45        Dropout
# 46        Dropout
# 47        Dropout
# ...
